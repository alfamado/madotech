# %%
import pandas as pd
import os

# %%
df = pd.read_csv("sales_data.xls")

# %%
df.head()
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 1        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 3       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
# ...

# %%
df.dtypes
# Out:
# customer_id        object
# device_id          object
# item_id             int64
# line_item_id        int64
# order_id           object
# event_id            int64
# event_timestamp    object
# quantity            int64
# currency           object
# checked_out_at     object
# status             object
# location           object
# dtype: object

# %%
df.describe()
# Out:
#              item_id   line_item_id       event_id       quantity
# count  578320.000000  578320.000000  578320.000000  578320.000000
# mean        7.995741   19034.444880   88235.379821       3.009861
# std         4.322902    9153.541683   42541.874688       1.406914
# min         1.000000    3201.000000   14786.000000       1.000000
# 25%         4.000000   11108.000000   51318.000000       2.000000
# 50%         8.000000   19067.000000   88373.000000       3.000000
# 75%        12.000000   26960.000000  125003.000000       4.000000
# max        15.000000   34941.000000  161960.000000       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578320 entries, 0 to 578319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   customer_id      578320 non-null  object
#  1   device_id        578320 non-null  object
#  2   item_id          578320 non-null  int64
#  3   line_item_id     578320 non-null  int64
#  4   order_id         578320 non-null  object
#  5   event_id         578320 non-null  int64
#  6   event_timestamp  578320 non-null  object
#  7   quantity         578320 non-null  int64
#  8   currency         578320 non-null  object
#  9   checked_out_at   578320 non-null  object
#  10  status           578320 non-null  object
#  11  location         578320 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 52.9+ MB

# %%
df.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status', 'location'],
#       dtype='object')

# %%
df.loc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
df.iloc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
df.iloc[[0,2,4,6],[0,1,2,3]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id
# 0        4          3201
# 2        9          3203
# 4        6          3205
# 6        4          3201

# %%
df.loc[[0,2,4,6],['customer_id', 'device_id','item_id']]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 2        9
# 4        6
# 6        4

# %%
df.iloc[::]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.iloc[:]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.iloc[-1:]
# Out:
#                                  customer_id  \
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 578319  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
#
#                                     order_id  event_id  \
# 578319  ad73a2a0-354a-40bf-81cd-ff017ac859d5    161960
#
#                    event_timestamp  quantity currency  \
# 578319  2024-03-30 04:14:18.224200         3      USD
#
#                     checked_out_at  status          location
# 578319  2024-03-30 04:14:18.224200  failed  Christmas Island

# %%
df.iloc[:-1]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578314  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.loc[0:4,'customer_id':'item_id']
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 1        5
# 2        9
# 3       12
# 4        6

# %%
df.iloc[0:4,1:4]
# Out:
#                               device_id  item_id  line_item_id
# 0  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3  33b485de-7338-4997-b1d0-b988ba17b245       12          3204

# %%
df.iloc[0:-1,2:5]
# Out:
#         item_id  line_item_id                              order_id
# 0             4          3201  9e950ce3-2e12-479c-a051-493c1a497d49
# 1             5          3202  9e950ce3-2e12-479c-a051-493c1a497d49
# 2             9          3203  9e950ce3-2e12-479c-a051-493c1a497d49
# 3            12          3204  9e950ce3-2e12-479c-a051-493c1a497d49
# 4             6          3205  9e950ce3-2e12-479c-a051-493c1a497d49
# ...         ...           ...                                   ...
# 578314        4         34940  ad73a2a0-354a-40bf-81cd-ff017ac859d5
# 578315        1         34941  ad73a2a0-354a-40bf-81cd-ff017ac859d5
# 578316        4         34940  ad73a2a0-354a-40bf-81cd-ff017ac859d5
# 578317        1         34941  ad73a2a0-354a-40bf-81cd-ff017ac859d5
# 578318        4         34940  ad73a2a0-354a-40bf-81cd-ff017ac859d5
#
# [578319 rows x 3 columns]

# %%
df.set_index("location", inplace=True)

# %%
df.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
df.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578320)

# %%
df.index.unique().sort_values()
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica (the territory South of 60 deg S)',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=243)

# %%
df.index.value_counts().head(8)
# Out:
# location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Name: count, dtype: int64

# %%
df.index.value_counts().head(8).plot(kind="bar")
# Out:
# <Axes: xlabel='location'>

# %%
df.index.value_counts().head(20).plot(kind="bar", figsize=(10,20))
# Out:
# <Axes: xlabel='location'>

# %%
df.index.nunique()
# Out:
# 243

# %%
len(df.columns)
# Out:
# 11

# %%
df.loc["Nigeria"]
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
df[df["customer_id"] == "8aabfc1a-4395-4e8b-82b4-6e8cc2b07586"]
# Out:
#                                    customer_id  \
# location
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        8         32694
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       10         32695
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        1         32696
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        3         32697
# ...

# %%
df["customer_id"].nunique()
# Out:
# 4594

# %%
df["customer_id"].value_counts().sort_values(ascending=False).head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='customer_id'>

# %%
call = (df["customer_id"] == "8aabfc1a-4395-4e8b-82b4-6e8cc2b07586")

# %%
df[call].head(3)
# Out:
#                                    customer_id  \
# location
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        8         32694
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       10         32695
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        1         32696
#
#                                       order_id  event_id  \
# location
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
#
#                      event_timestamp  quantity currency  \
# location
# Nigeria   2024-03-30 04:03:17.599327         5      GBP
# Nigeria   2024-03-30 04:03:17.599327         1      GBP
# ...

# %%
df.loc[call].head(3)
# Out:
#                                    customer_id  \
# location
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        8         32694
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       10         32695
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        1         32696
#
#                                       order_id  event_id  \
# location
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
# Nigeria   9428b052-c011-4a1e-9dc4-48307aed5c8b    151785
#
#                      event_timestamp  quantity currency  \
# location
# Nigeria   2024-03-30 04:03:17.599327         5      GBP
# Nigeria   2024-03-30 04:03:17.599327         1      GBP
# ...

# %%
df.loc[call,"customer_id":"currency"].value_counts()
# Out:
# customer_id                           device_id                             item_id  line_item_id  order_id                              event_id  event_timestamp             quantity  currency
# 8aabfc1a-4395-4e8b-82b4-6e8cc2b07586  5843c4cf-75c8-4f99-a6ec-e0392cd5bb23  1        32696         9428b052-c011-4a1e-9dc4-48307aed5c8b  151785    2024-03-30 04:03:17.599327  3         GBP         1
#                                                                                                                                          151786    2024-03-30 04:03:17.599329  3         GBP         1
#                                                                                                                                          151787    2024-03-30 04:03:17.599330  3         GBP         1
#                                                                                                                                          151788    2024-03-30 04:03:17.599331  3         GBP         1
# ...

# %%
df["currency"].unique()
# Out:
# array(['NGN', 'USD', 'GBP'], dtype=object)

# %%
df["currency"].value_counts()
# Out:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %%
df["currency"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='currency'>

# %%
call = (df["customer_id"] == "8aabfc1a-4395-4e8b-82b4-6e8cc2b07586")

# %%
call2 = (df["customer_id"] == "8aabfc1a-4395-4e8b-82b4-6e8cc2b07586") & (df["status"] == "success")

# %%
df.loc[call2]
# Out:
#                                    customer_id  \
# location
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        8         32694
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       10         32695
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        1         32696
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        3         32697
# ...

# %%
customer_hello = df.loc[call2]

# %%
customer_hello["status"].value_counts()
# Out:
# status
# success    105
# Name: count, dtype: int64

# %%
call3 = (df["status"] == "failed")

# %%
df.loc[call3]
# Out:
#                                            customer_id  \
# location
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali              f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# ...

# %%
df["status"].value_counts()
# Out:
# status
# failed       196383
# success      192594
# cancelled    189343
# Name: count, dtype: int64

# %%
df["status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='status'>

# %%
df.groupby("status")["currency"].value_counts()
# Out:
# status     currency
# cancelled  USD         67672
#            GBP         64324
#            NGN         57347
# failed     USD         68183
#            NGN         65387
#            GBP         62813
# success    NGN         66146
#            GBP         64266
#            USD         62182
# Name: count, dtype: int64

# %%
df.groupby("status")["currency"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='status,currency'>

# %%
rwanda = df.loc["Rwanda"]
rwanda.head()
# Out:
#                                    customer_id  \
# location
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
#
#                                      device_id  item_id  line_item_id  \
# location
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        5          3784
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        4          3785
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        7          3786
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389       11          3787
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        2          3788
#
#                                       order_id  event_id  \
# location
# Rwanda    98929aea-685c-4730-a835-34609861db71     17615
# Rwanda    98929aea-685c-4730-a835-34609861db71     17615
# ...

# %%
rwanda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2986 entries, Rwanda to Rwanda
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2986 non-null   object
#  1   device_id        2986 non-null   object
#  2   item_id          2986 non-null   int64
#  3   line_item_id     2986 non-null   int64
#  4   order_id         2986 non-null   object
#  5   event_id         2986 non-null   int64
#  6   event_timestamp  2986 non-null   object
#  7   quantity         2986 non-null   int64
#  8   currency         2986 non-null   object
#  9   checked_out_at   2986 non-null   object
#  10  status           2986 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 344.5+ KB

# %%
rwanda.shape
# Out:
# (2986, 11)

# %%
rwanda.shape[0]
# Out:
# 2986

# %%
transaction_success = rwanda[rwanda["status"] == "success"]
transaction_failed = rwanda[rwanda["status"] == "failed"]
transaction_cancelled = rwanda[rwanda["status"] == "cancelled"]

# %%
transaction_success.head()
# Out:
#                                    customer_id  \
# location
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
# Rwanda    b3e27402-9060-4fa4-b199-47945b6fda47
#
#                                      device_id  item_id  line_item_id  \
# location
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        5          3784
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        4          3785
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        7          3786
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389       11          3787
# Rwanda    408c5d12-c455-49b4-9dea-1ac5263cf389        2          3788
#
#                                       order_id  event_id  \
# location
# Rwanda    98929aea-685c-4730-a835-34609861db71     17615
# Rwanda    98929aea-685c-4730-a835-34609861db71     17615
# ...

# %%
transaction_success.shape[0]
# Out:
# 1170

# %%
transaction_cancelled.shape[0]
# Out:
# 180

# %%
transaction_failed.shape[0]
# Out:
# 1636

# %%
transaction_failed.customer_id.nunique()
# Out:
# 10

# %%
transaction_failed.customer_id.unique()
# Out:
# array(['a10fd89b-9bc6-4dec-bcde-222352771b59',
#        '7fa3d717-37ec-4c2b-83dc-9d88a5fa8acc',
#        '55e93b10-23e8-4508-ba47-bac055aee030',
#        'b932b5a5-643e-4ed9-8e4e-a005dd93d61d',
#        'e55e6785-b35c-4fb3-b2f7-029c73a51379',
#        'beec4c6f-0a8e-4573-8ff2-6a8014a6675d',
#        '57b19064-143f-414c-a846-f7464d7e5a10',
#        '56dee386-ba70-40fd-b860-05f7ea7907f1',
#        '620bdff1-3275-4c4d-b111-2ec99ffe8c77',
#        'ccc1084c-0549-4b1b-80ba-8fe4a2fa22d6'], dtype=object)

# %%
customer_620bdff1 = transaction_failed[transaction_failed["customer_id"] == "620bdff1-3275-4c4d-b111-2ec99ffe8c77"]

# %%
customer_620bdff1.head()
# Out:
#                                    customer_id  \
# location
# Rwanda    620bdff1-3275-4c4d-b111-2ec99ffe8c77
# Rwanda    620bdff1-3275-4c4d-b111-2ec99ffe8c77
# Rwanda    620bdff1-3275-4c4d-b111-2ec99ffe8c77
# Rwanda    620bdff1-3275-4c4d-b111-2ec99ffe8c77
# Rwanda    620bdff1-3275-4c4d-b111-2ec99ffe8c77
#
#                                      device_id  item_id  line_item_id  \
# location
# Rwanda    e68a279e-4f02-456f-a188-8791715cdaf4       11         32461
# Rwanda    e68a279e-4f02-456f-a188-8791715cdaf4       12         32462
# Rwanda    e68a279e-4f02-456f-a188-8791715cdaf4        7         32463
# Rwanda    e68a279e-4f02-456f-a188-8791715cdaf4        8         32464
# Rwanda    e68a279e-4f02-456f-a188-8791715cdaf4       13         32465
#
#                                       order_id  event_id  \
# location
# Rwanda    1eb9dc3b-bb76-4c78-a7c0-2b719747dc8f    150675
# Rwanda    1eb9dc3b-bb76-4c78-a7c0-2b719747dc8f    150675
# ...

# %%
customer_620bdff1.shape[0]
# Out:
# 84

# %%
customer_620bdff1.currency.unique()
# Out:
# array(['NGN'], dtype=object)

# %%
transaction_success[transaction_success["customer_id"] == "620bdff1-3275-4c4d-b111-2ec99ffe8c77"]
# Out:
# Empty DataFrame
# Columns: [customer_id, device_id, item_id, line_item_id, order_id, event_id, event_timestamp, quantity, currency, checked_out_at, status]
# Index: []

# %%
customer_620bdff1["event_timestamp"].value_counts()
# Out:
# event_timestamp
# 2024-03-30 04:03:17.540141    6
# 2024-03-30 04:03:17.540142    6
# 2024-03-30 04:03:17.540143    6
# 2024-03-30 04:03:17.540188    6
# 2024-03-30 04:03:17.540190    6
# 2024-03-30 04:03:17.540191    6
# 2024-03-30 04:03:17.540193    6
# 2024-03-30 04:03:17.540194    6
# 2024-03-30 04:03:17.540195    6
# 2024-03-30 04:03:17.540197    6
# 2024-03-30 04:03:17.540198    6
# 2024-03-30 04:03:17.540199    6
# 2024-03-30 04:03:17.540201    6
# 2024-03-30 04:08:17.540203    6
# Name: count, dtype: int64

# %%
customer_620bdff1["quantity"].sort_values(ascending=False)
# Out:
# location
# Rwanda    5
# Rwanda    5
# Rwanda    5
# Rwanda    5
# Rwanda    5
#          ..
# Rwanda    2
# Rwanda    2
# Rwanda    2
# Rwanda    2
# Rwanda    2
# Name: quantity, Length: 84, dtype: int64

# %%
customer_620bdff1["order_id"].value_counts()
# Out:
# order_id
# 1eb9dc3b-bb76-4c78-a7c0-2b719747dc8f    84
# Name: count, dtype: int64

# %%
customer_620bdff1["item_id"].unique()
# Out:
# array([11, 12,  7,  8, 13,  1])

# %%
customer_620bdff1["item_id"].value_counts()
# Out:
# item_id
# 11    14
# 12    14
# 7     14
# 8     14
# 13    14
# 1     14
# Name: count, dtype: int64

# %%
customer_620bdff1["event_id"].nunique()
# Out:
# 14

# %%
customer_620bdff1["event_id"].value_counts()
# Out:
# event_id
# 150675    6
# 150676    6
# 150677    6
# 150678    6
# 150679    6
# 150680    6
# 150681    6
# 150682    6
# 150683    6
# 150684    6
# 150685    6
# 150686    6
# 150687    6
# 150688    6
# Name: count, dtype: int64

# %%
customer_620bdff1.duplicated().sum()
# Out:
# np.int64(0)

# %%
rwanda.currency.unique()
# Out:
# array(['GBP', 'USD', 'NGN'], dtype=object)

# %%
rwanda.currency.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='currency'>

# %%
rwanda.status.value_counts()
# Out:
# status
# failed       1636
# success      1170
# cancelled     180
# Name: count, dtype: int64

# %%
rwanda.status.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='status'>

# %%
rwanda.status.value_counts().plot(kind="pie", autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
rwanda.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
rwanda["customer_id"].unique()
# Out:
# array(['b3e27402-9060-4fa4-b199-47945b6fda47',
#        '64e6f392-2e3e-4ce2-910f-0ed2a21a6642',
#        'a10fd89b-9bc6-4dec-bcde-222352771b59',
#        '7fa3d717-37ec-4c2b-83dc-9d88a5fa8acc',
#        '55e93b10-23e8-4508-ba47-bac055aee030',
#        '5974478a-f970-44e9-b9b8-09819a3a389b',
#        'd9c81423-70b5-476f-a6c4-76c20b5f8c2a',
#        '29f8fdbd-4908-4197-8229-bf1d89d9b47f',
#        'df4cf418-6255-4d2f-8ad5-883218ad48e6',
#        '444ca6b0-f26f-4a78-b1a3-693557dd6771',
#        'bd160765-5611-44d7-af57-53dbb4e867ad',
#        '69608fc7-4f70-4f21-abfc-f938bd7780fb',
#        'b932b5a5-643e-4ed9-8e4e-a005dd93d61d',
#        'e55e6785-b35c-4fb3-b2f7-029c73a51379',
#        '0b3d75ed-2143-4b32-8b52-e45d8f8a2de6',
#        'beec4c6f-0a8e-4573-8ff2-6a8014a6675d',
#        'b5d8abfe-0a78-45ce-98a2-9845446ff6b6',
#        'a794c470-f611-4403-8779-bb84401798b9',
#        '80a296c4-b427-4254-88e6-bcd7ac896631',
#        '57b19064-143f-414c-a846-f7464d7e5a10',
# ...

# %%
rwanda.groupby("status")["currency"].value_counts()
# Out:
# status     currency
# cancelled  GBP         112
#            USD          68
# failed     NGN         904
#            GBP         393
#            USD         339
# success    GBP         545
#            USD         424
#            NGN         201
# Name: count, dtype: int64

# %%
rwanda.currency.value_counts().plot(kind="pie", autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
rwanda.groupby("status")["currency"].value_counts().plot(kind="pie", autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# From my research on country Rwanda based on the data produced, the percentage of successful transaction was just 39% less than half of the total transaction. I dived in further to look at the cause, at first I couldn't pinpoint it out, then I looked at the currency of transaction.
# There are three major trading currency which are naira, dollar and pounds. Naira was the highest trading currency in Rwanda with a percentage of 37% out of 2986 transactions but only 6.7% was a success which really shows only 18.1% success rate, compared to other currency like pounds and dollars with over 50% success rate.

# %%
call4 = (df["status"].str.contains("failed"))

# %%
df.loc[call4].head()
# Out:
#                                    customer_id  \
# location
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali      f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
#
#                                      device_id  item_id  line_item_id  \
# location
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Mali      76c265ff-c670-433a-887f-4b0d7a991349        4          3215
#
#                                       order_id  event_id  \
# location
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14800
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14801
# ...

# %%
df.loc[~call4].head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
df.head(3)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          event_timestamp  quantity currency  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578320 entries, Saint Helena to Christmas Island
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   customer_id      578320 non-null  object
#  1   device_id        578320 non-null  object
#  2   item_id          578320 non-null  int64
#  3   line_item_id     578320 non-null  int64
#  4   order_id         578320 non-null  object
#  5   event_id         578320 non-null  int64
#  6   event_timestamp  578320 non-null  object
#  7   quantity         578320 non-null  int64
#  8   currency         578320 non-null  object
#  9   checked_out_at   578320 non-null  object
#  10  status           578320 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 69.1+ MB

# %%
df.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
copy_df = df.copy()

# %%
copy_df.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
copy_df.rename(columns= {"customer_id":"Customer_ID"}, inplace=True)

# %%
copy_df.columns
# Out:
# Index(['Customer_ID', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
copy_df.rename(columns= {"device_id":"Device_ID"}, inplace=True)

# %%
copy_df.columns
# Out:
# Index(['Customer_ID', 'Device_ID', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
copy_df.columns = copy_df.columns.str.upper()

# %%
copy_df.head(2)
# Out:
#                                        CUSTOMER_ID  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          DEVICE_ID  ITEM_ID  LINE_ITEM_ID  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
#
#                                           ORDER_ID  EVENT_ID  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          EVENT_TIMESTAMP  QUANTITY CURRENCY  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
# Saint Helena  2024-03-26 22:05:58.863661         4      NGN
#
#                           CHECKED_OUT_AT   STATUS
# location
# Saint Helena  2024-03-30 04:19:10.406794  success
# Saint Helena  2024-03-30 04:19:10.406794  success

# %%
copy_df.columns = copy_df.columns.str.lower()

# %%
copy_df.head(2)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          event_timestamp  quantity currency  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
# Saint Helena  2024-03-26 22:05:58.863661         4      NGN
#
#                           checked_out_at   status
# location
# Saint Helena  2024-03-30 04:19:10.406794  success
# Saint Helena  2024-03-30 04:19:10.406794  success

# %%
copy_df.columns = [y.upper() for y in copy_df.columns]

# %%
copy_df.columns
# Out:
# Index(['CUSTOMER_ID', 'DEVICE_ID', 'ITEM_ID', 'LINE_ITEM_ID', 'ORDER_ID',
#        'EVENT_ID', 'EVENT_TIMESTAMP', 'QUANTITY', 'CURRENCY', 'CHECKED_OUT_AT',
#        'STATUS'],
#       dtype='object')

# %%
copy_df.columns = [y.lower() for y in copy_df.columns]

# %%
copy_df.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
copy_df.columns = copy_df.columns.str.replace("_","")

# %%
copy_df.columns
# Out:
# Index(['customerid', 'deviceid', 'itemid', 'lineitemid', 'orderid', 'eventid',
#        'eventtimestamp', 'quantity', 'currency', 'checkedoutat', 'status'],
#       dtype='object')

# %%
copy_df.head()
# Out:
#                                         customerid  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                           deviceid  itemid  lineitemid  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       4        3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       5        3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       9        3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245      12        3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       6        3205
#
#                                            orderid  eventid  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49    14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49    14786
# ...

# %%
copy_df.apply(len)
# Out:
# customerid        578320
# deviceid          578320
# itemid            578320
# lineitemid        578320
# orderid           578320
# eventid           578320
# eventtimestamp    578320
# quantity          578320
# currency          578320
# checkedoutat      578320
# status            578320
# dtype: int64

# %%
copy_df.columns
# Out:
# Index(['customerid', 'deviceid', 'itemid', 'lineitemid', 'orderid', 'eventid',
#        'eventtimestamp', 'quantity', 'currency', 'checkedoutat', 'status'],
#       dtype='object')

# %%
copy_df.apply(lambda y:y.min())
# Out:
# customerid        00096d0c-ced3-4913-afe9-5ce363f7126f
# deviceid          000f53e2-b76e-4d2e-9db1-123c9535b5dc
# itemid                                               1
# lineitemid                                        3201
# orderid           0013dca7-52fe-4794-ad3b-7b30958b368f
# eventid                                          14786
# eventtimestamp              2024-03-19 04:06:12.469246
# quantity                                             1
# currency                                           GBP
# checkedoutat                2024-03-30 04:06:10.418189
# status                                       cancelled
# dtype: object

# %%
copy_df.apply(lambda y:y.max())
# Out:
# customerid        ffef23aa-84f4-45ba-96cc-2c4377220305
# deviceid          fff883b4-569c-4620-9308-d185a3ec33c8
# itemid                                              15
# lineitemid                                       34941
# orderid           fffcfc29-d713-4ca2-aa7b-36466cbda9d3
# eventid                                         161960
# eventtimestamp              2024-03-30 04:20:18.189028
# quantity                                             5
# currency                                           USD
# checkedoutat                2024-03-30 04:20:18.189028
# status                                         success
# dtype: object

# %%
copy_df["status"].apply(len)
# Out:
# location
# Saint Helena        7
# Saint Helena        7
# Saint Helena        7
# Saint Helena        7
# Saint Helena        7
#                    ..
# Christmas Island    6
# Christmas Island    6
# Christmas Island    6
# Christmas Island    6
# Christmas Island    6
# Name: status, Length: 578320, dtype: int64

# %%
def case_capital(y):
    return y.upper()

# %%
copy_df["status"].apply(case_capital)
# Out:
# location
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
#                      ...
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Name: status, Length: 578320, dtype: object

# %%
copy_df["status"].apply(lambda y : y.lower())
# Out:
# location
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
#                      ...
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Name: status, Length: 578320, dtype: object

# %%
copy_df.columns
# Out:
# Index(['customerid', 'deviceid', 'itemid', 'lineitemid', 'orderid', 'eventid',
#        'eventtimestamp', 'quantity', 'currency', 'checkedoutat', 'status'],
#       dtype='object')

# %%
copy_df2 = copy_df[["currency","status"]]

# %%
copy_df2.head()
# Out:
#              currency   status
# location
# Saint Helena      NGN  success
# Saint Helena      NGN  success
# Saint Helena      NGN  success
# Saint Helena      NGN  success
# Saint Helena      NGN  success

# %%
copy_df2.map(str.upper)
# Out:
#                  currency   status
# location
# Saint Helena          NGN  SUCCESS
# Saint Helena          NGN  SUCCESS
# Saint Helena          NGN  SUCCESS
# Saint Helena          NGN  SUCCESS
# Saint Helena          NGN  SUCCESS
# ...                   ...      ...
# Christmas Island      USD   FAILED
# Christmas Island      USD   FAILED
# Christmas Island      USD   FAILED
# Christmas Island      USD   FAILED
# Christmas Island      USD   FAILED
#
# [578320 rows x 2 columns]

# %%
copy_df2.map(str.lower)
# Out:
#                  currency   status
# location
# Saint Helena          ngn  success
# Saint Helena          ngn  success
# Saint Helena          ngn  success
# Saint Helena          ngn  success
# Saint Helena          ngn  success
# ...                   ...      ...
# Christmas Island      usd   failed
# Christmas Island      usd   failed
# Christmas Island      usd   failed
# Christmas Island      usd   failed
# Christmas Island      usd   failed
#
# [578320 rows x 2 columns]

# %%
copy_df3 = copy_df.copy()[-15:-1]

# %%
copy_df3.head(10)
# Out:
#                                             customerid  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                               deviceid  itemid  lineitemid  \
# location
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e       1       34941
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e       4       34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e       1       34941
# ...

# %%
copy_df3.shape
# Out:
# (14, 11)

# %%
copy_df3["currency"] = copy_df3["currency"].map({"USD":"EUR"})

# %%
copy_df3["currency"]
# Out:
# location
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Christmas Island    EUR
# Name: currency, dtype: object

# %%
copy_df3
# Out:
#                                             customerid  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                               deviceid  itemid  lineitemid  \
# location
# ...

# %%
copy_df3["currency"] = copy_df3["currency"].replace({"EUR":"USD"})

# %%
copy_df3["currency"]
# Out:
# location
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Name: currency, dtype: object

# %%
copy_df3
# Out:
#                                             customerid  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                               deviceid  itemid  lineitemid  \
# location
# ...

# %%
import numpy as np

# %%
loop = copy_df[["quantity","currency","status"]].reset_index()

# %%
loop.head()
# Out:
#        location  quantity currency   status
# 0  Saint Helena         2      NGN  success
# 1  Saint Helena         4      NGN  success
# 2  Saint Helena         5      NGN  success
# 3  Saint Helena         1      NGN  success
# 4  Saint Helena         2      NGN  success

# %%
loop["status"].unique()
# Out:
# array(['success', 'failed', 'cancelled'], dtype=object)

# %%
loop["payment_stat_abr"] = np.nan

# %%
loop.head()
# Out:
#        location  quantity currency   status  payment_stat_abr
# 0  Saint Helena         2      NGN  success               NaN
# 1  Saint Helena         4      NGN  success               NaN
# 2  Saint Helena         5      NGN  success               NaN
# 3  Saint Helena         1      NGN  success               NaN
# 4  Saint Helena         2      NGN  success               NaN

# %%
loop["status"].str.strip()
# Out:
# 0         success
# 1         success
# 2         success
# 3         success
# 4         success
#            ...
# 578315     failed
# 578316     failed
# 578317     failed
# 578318     failed
# 578319     failed
# Name: status, Length: 578320, dtype: object

# %%
for i in range(len(loop)):
    if loop["status"][i] == "success":
        loop["payment_stat_abr"][i] = "s"
    elif loop["status"][i] == "failed":
        loop["payment_stat_abr"][i] = "f"
    else:
        loop["payment_stat_abr"][i] = "c"
# Out:
# C:\Users\Cebrail\AppData\Local\Temp\ipykernel_12548\3913995322.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   loop["payment_stat_abr"][i] = "s"
# ...

# %%
loop.head()
# Out:
#        location  quantity currency   status payment_stat_abr
# 0  Saint Helena         2      NGN  success                s
# 1  Saint Helena         4      NGN  success                s
# 2  Saint Helena         5      NGN  success                s
# 3  Saint Helena         1      NGN  success                s
# 4  Saint Helena         2      NGN  success                s

# %%
# calls = loop["status"] == "success"
# callf = loop["status"] == "failed"
# callc = loop["status"] == "cancelled"

# %%
# loop.loc[calls,"payement_stat_abr"] = "s"
# loop.loc[callf,"payement_stat_abr"] = "f"
# loop.loc[callc,"payement_stat_abr"] = "c"

# %%
dictions = {'success':'s','failed':'f','cancelled':'c'}

# %%
def fasterloop(df,search_col_name, applycolumns,dictionaryofvalues,elsevalue = ""):
    for i, j in dictions.items():
        call = df[search_col_name] == i
        df.loc[call,applycolumns] == j
    if elsevalue == "":
        pass
    else:
        df = df[applycolumns.fillna(elsevalue)]

# %%
fasterloop(loop,"status","payment_stat_abr",dictions)

# %%
loop.head()
# Out:
#        location  quantity currency   status payment_stat_abr
# 0  Saint Helena         2      NGN  success                s
# 1  Saint Helena         4      NGN  success                s
# 2  Saint Helena         5      NGN  success                s
# 3  Saint Helena         1      NGN  success                s
# 4  Saint Helena         2      NGN  success                s

# %%
loop.drop(index=2, inplace=True)

# %%
loop.head()
# Out:
#        location  quantity currency   status payment_stat_abr
# 0  Saint Helena         2      NGN  success                s
# 1  Saint Helena         4      NGN  success                s
# 3  Saint Helena         1      NGN  success                s
# 4  Saint Helena         2      NGN  success                s
# 5  Saint Helena         4      NGN  success                s

# %%
loop.drop(index= [0,4,6], inplace= True)

# %%
loop.head(10)
# Out:
#         location  quantity currency   status payment_stat_abr
# 1   Saint Helena         4      NGN  success                s
# 3   Saint Helena         1      NGN  success                s
# 5   Saint Helena         4      NGN  success                s
# 7   Saint Helena         4      NGN  success                s
# 8   Saint Helena         5      NGN  success                s
# 9   Saint Helena         1      NGN  success                s
# 10  Saint Helena         2      NGN  success                s
# 11  Saint Helena         4      NGN  success                s
# 12  Saint Helena         2      NGN  success                s
# 13  Saint Helena         4      NGN  success                s

# %%
call = loop["quantity"] >= 4

# %%
loop[call].index
# Out:
# Index([     1,      5,      7,      8,     11,     13,     14,     17,     19,
#            20,
#        ...
#        578250, 578255, 578260, 578265, 578270, 578275, 578280, 578285, 578290,
#        578295],
#       dtype='int64', length=232162)

# %%
most_quant = loop.drop(index=loop[~call].index)

# %%
most_quant
# Out:
#              location  quantity currency     status payment_stat_abr
# 1        Saint Helena         4      NGN    success                s
# 5        Saint Helena         4      NGN    success                s
# 7        Saint Helena         4      NGN    success                s
# 8        Saint Helena         5      NGN    success                s
# 11       Saint Helena         4      NGN    success                s
# ...               ...       ...      ...        ...              ...
# 578275  Liechtenstein         4      GBP  cancelled                c
# 578280  Liechtenstein         4      GBP  cancelled                c
# 578285  Liechtenstein         4      GBP  cancelled                c
# 578290  Liechtenstein         4      GBP  cancelled                c
# 578295  Liechtenstein         4      GBP  cancelled                c
#
# [232162 rows x 5 columns]

# %%
make_index = loop.copy()

# %%
make_index.set_index("location", inplace=True)

# %%
make_index.head()
# Out:
#               quantity currency   status payment_stat_abr
# location
# Saint Helena         4      NGN  success                s
# Saint Helena         1      NGN  success                s
# Saint Helena         4      NGN  success                s
# Saint Helena         4      NGN  success                s
# Saint Helena         5      NGN  success                s

# %%
make_index.shape
# Out:
# (578316, 4)

# %%
make_index.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578316)

# %%
make_index.drop(index="Saint Helena", inplace=True)

# %%
make_index.head()
# Out:
#           quantity currency     status payment_stat_abr
# location
# Djibouti         3      NGN     failed                f
# Djibouti         3      NGN     failed                f
# Djibouti         3      NGN     failed                f
# Djibouti         3      NGN     failed                f
# Ecuador          2      USD  cancelled                c

# %%
make_index.sort_values(by = "quantity").head(10)
# Out:
#            quantity currency     status payment_stat_abr
# location
# Canada            1      GBP     failed                f
# Canada            1      GBP     failed                f
# Canada            1      GBP     failed                f
# Canada            1      GBP     failed                f
# Canada            1      GBP     failed                f
# Canada            1      GBP     failed                f
# Ecuador           1      USD  cancelled                c
# Ecuador           1      USD  cancelled                c
# Argentina         1      NGN    success                s
# Argentina         1      NGN    success                s

# %%
make_index.sort_values(by="status", ascending=True).head()
# Out:
#           quantity currency     status payment_stat_abr
# location
# Togo             4      NGN  cancelled                c
# Latvia           1      GBP  cancelled                c
# Latvia           1      GBP  cancelled                c
# Latvia           3      GBP  cancelled                c
# Latvia           2      GBP  cancelled                c

# %%
make_index.sort_values(by=["quantity","currency"]).head()
# Out:
#                        quantity currency  status payment_stat_abr
# location
# Palestinian Territory         1      GBP  failed                f
# Palestinian Territory         1      GBP  failed                f
# Palestinian Territory         1      GBP  failed                f
# Palestinian Territory         1      GBP  failed                f
# Palestinian Territory         1      GBP  failed                f

# %%
make_index.sort_values(by=["quantity","currency"], ascending=[True,False]).head()
# Out:
#           quantity currency     status payment_stat_abr
# location
# Ecuador          1      USD  cancelled                c
# Ecuador          1      USD  cancelled                c
# Ecuador          1      USD  cancelled                c
# Ecuador          1      USD  cancelled                c
# Ecuador          1      USD  cancelled                c

# %%
make_index.index.sort_values(ascending=False)
# Out:
# Index(['Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        ...
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan'],
#       dtype='object', name='location', length=575475)

# %%
make_index.sort_index(inplace=True)

# %%
make_index
# Out:
#              quantity currency     status payment_stat_abr
# location
# Afghanistan         4      NGN    success                s
# Afghanistan         2      USD  cancelled                c
# Afghanistan         1      USD  cancelled                c
# Afghanistan         4      USD  cancelled                c
# Afghanistan         5      USD  cancelled                c
# ...               ...      ...        ...              ...
# Zimbabwe            2      GBP  cancelled                c
# Zimbabwe            5      GBP  cancelled                c
# Zimbabwe            1      GBP  cancelled                c
# Zimbabwe            5      GBP  cancelled                c
# Zimbabwe            2      USD  cancelled                c
#
# [575475 rows x 4 columns]

# %%
make_index.dtypes
# Out:
# quantity             int64
# currency            object
# status              object
# payment_stat_abr    object
# dtype: object

# %%
grouped_df = make_index

# %%
grouped = grouped_df.groupby(["status"])

# %%
grouped["quantity"].count()
# Out:
# status
# cancelled    188287
# failed       195438
# success      191750
# Name: quantity, dtype: int64

# %%
grouped["quantity"].describe()[['min','max','mean']]
# Out:
#            min  max      mean
# status
# cancelled  1.0  5.0  3.014547
# failed     1.0  5.0  3.017688
# success    1.0  5.0  2.998096

# %%
grouped["quantity"].agg(["min","max","count"])
# Out:
#            min  max   count
# status
# cancelled    1    5  188287
# failed       1    5  195438
# success      1    5  191750

# %%
failed = grouped.get_group("failed")
failed.head()
# Out:
# C:\Users\Cebrail\AppData\Local\Temp\ipykernel_12548\2840267646.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   failed = grouped.get_group("failed")
#              quantity currency  status payment_stat_abr
# location
# Afghanistan         3      NGN  failed                f
# Afghanistan         3      NGN  failed                f
# Afghanistan         3      NGN  failed                f
# Afghanistan         3      NGN  failed                f
# Afghanistan         5      NGN  failed                f

# %%
success = grouped.get_group("success")
success.head()
# Out:
# C:\Users\Cebrail\AppData\Local\Temp\ipykernel_12548\2687549641.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   success = grouped.get_group("success")
#              quantity currency   status payment_stat_abr
# location
# Afghanistan         4      NGN  success                s
# Afghanistan         5      NGN  success                s
# Afghanistan         5      GBP  success                s
# Afghanistan         5      GBP  success                s
# Afghanistan         5      GBP  success                s

# %%
cancelled = grouped.get_group("cancelled")
cancelled.head()
# Out:
# C:\Users\Cebrail\AppData\Local\Temp\ipykernel_12548\1327541094.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   cancelled = grouped.get_group("cancelled")
#              quantity currency     status payment_stat_abr
# location
# Afghanistan         2      USD  cancelled                c
# Afghanistan         1      USD  cancelled                c
# Afghanistan         4      USD  cancelled                c
# Afghanistan         5      USD  cancelled                c
# Afghanistan         5      USD  cancelled                c

# %%
cancelled["currency"].unique()
# Out:
# array(['USD', 'GBP', 'NGN'], dtype=object)

# %%
cancelled["quantity"].describe().T
# Out:
# count    188287.000000
# mean          3.014547
# std           1.402927
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: quantity, dtype: float64

# %%
grouped["quantity"].describe()[["min","max"]].sort_values(by = "min")
# Out:
#            min  max
# status
# cancelled  1.0  5.0
# failed     1.0  5.0
# success    1.0  5.0

# %%
len(make_index["currency"].unique())
# Out:
# 3

# %%
make_index["currency"].nunique()
# Out:
# 3

# %%
df.head(4)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
df.set_index("event_timestamp",inplace = True)

# %%
df.head()
# Out:
#                                                      customer_id  \
# event_timestamp
# 2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                                        device_id  item_id  \
# event_timestamp
# 2024-03-26 22:05:58.863661  33b485de-7338-4997-b1d0-b988ba17b245        4
# 2024-03-26 22:05:58.863661  33b485de-7338-4997-b1d0-b988ba17b245        5
# 2024-03-26 22:05:58.863661  33b485de-7338-4997-b1d0-b988ba17b245        9
# 2024-03-26 22:05:58.863661  33b485de-7338-4997-b1d0-b988ba17b245       12
# 2024-03-26 22:05:58.863661  33b485de-7338-4997-b1d0-b988ba17b245        6
#
#                             line_item_id  \
# event_timestamp
# ...

# %%
df.reset_index()
# Out:
#                    event_timestamp                           customer_id  \
# 0       2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       2024-03-26 22:05:58.863661  cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                            ...                                   ...
# 578315  2024-03-30 04:03:18.224196  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  2024-03-30 04:03:18.224198  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  2024-03-30 04:03:18.224198  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  2024-03-30 04:14:18.224200  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  2024-03-30 04:14:18.224200  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# ...
